# %% [markdown]
# ### Scryfall MKM Price Trend Harvester
#
# This program extracts magic the gathering (mtg) card price data (MKM Trend) at the time the code is run. It can also be used to gather a myriad of other card details that are provided in Sryfall's public API

# %%
#import libraries (these will have to be installed on your machine first, using pip)
import requests
import pandas as pd
import datetime

#This one is not necessary; but I work with a small screen so is helpful to utilise margins in jupyter nb
#Switch jupyter to enable multiple outputs per cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# #### Use the API to get MKM card prices
# See Scryfal REST API Docs at https://scryfall.com/docs/api
#
# I this example I am just using q=cmc:12 to query all cards with converted mana cost (cmc) of 12. But there are loads of other parameters you could use instead--and you can learn about them in the cards section of the API docs at the above link

# %%
#get a response object
response=requests.get('https://api.scryfall.com/cards/search?q=cmc:12')
print(response.status_code) #should be 200=ok
# Out:
# 200

# %% [markdown]
# This response code of 200 indicates that the request was successful (see https://restfulapi.net/http-status-codes/ for more info)

# %%
#look at response content
type(response.content) #bytes

#translate the response object's content from bytes to dictionary object so I can manipulate it
results=response.json() # .json() converts from bytes to dictionary
print(type(results)) #type of results in now dict (=dictionary)
print(results) #take a look at results--you can see most of what we want is somewhere in there
# Out:
# bytes
# <class 'dict'>
# {'object': 'list', 'total_cards': 5, 'has_more': False, 'data': [{'object': 'card', 'id': '7928bb14-7631-4830-a756-26d1ea832ba2', 'oracle_id': 'e80772e2-8623-4094-81a2-70828b2b151c', 'multiverse_ids': [221563], 'mtgo_id': 39587, 'mtgo_foil_id': 39588, 'name': 'Blightsteel Colossus', 'lang': 'en', 'uri': 'https://api.scryfall.com/cards/7928bb14-7631-4830-a756-26d1ea832ba2', 'scryfall_uri': 'https://scryfall.com/card/mbs/99/blightsteel-colossus?utm_source=api', 'layout': 'normal', 'highres_image': True, 'image_uris': {'small': 'https://img.scryfall.com/cards/small/en/mbs/99.jpg?1517813031', 'normal': 'https://img.scryfall.com/cards/normal/en/mbs/99.jpg?1517813031', 'large': 'https://img.scryfall.com/cards/large/en/mbs/99.jpg?1517813031', 'png': 'https://img.scryfall.com/cards/png/en/mbs/99.png?1517813031', 'art_crop': 'https://img.scryfall.com/cards/art_crop/en/mbs/99.jpg?1517813031', 'border_crop': 'https://img.scryfall.com/cards/border_crop/en/mbs/99.jpg?1517813031'}, 'mana_cost': '{12}', 'cmc': 12.0, 'type_line': 'Artifact Creature — Golem', 'oracle_text': "Trample, infect, indestructible\nIf Blightsteel Colossus would be put into a graveyard from anywhere, reveal Blightsteel Colossus and shuffle it into its owner's library instead.", 'power': '11', 'toughness': '11', 'colors': [], 'color_identity': [], 'legalities': {'standard': 'not_legal', 'future': 'not_legal', 'frontier': 'not_legal', 'modern': 'legal', 'legacy': 'legal', 'pauper': 'not_legal', 'vintage': 'legal', 'penny': 'not_legal', 'commander': 'legal', '1v1': 'legal', 'duel': 'legal', 'brawl': 'not_legal'}, 'reserved': False, 'foil': True, 'nonfoil': True, 'oversized': False, 'reprint': False, 'set': 'mbs', 'set_name': 'Mirrodin Besieged', 'set_uri': 'https://api.scryfall.com/sets/mbs', 'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Ambs&unique=prints', 'scryfall_set_uri': 'https://scryfall.com/sets/mbs?utm_source=api', 'rulings_uri': 'https://api.scryfall.com/cards/7928bb14-7631-4830-a756-26d1ea832ba2/rulings', 'prints_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=%21%E2%80%9CBlightsteel+Colossus%E2%80%9D+include%3Aextras&unique=prints', 'collector_number': '99', 'digital': False, 'rarity': 'mythic', 'watermark': 'phyrexian', 'illustration_id': '945af848-56b4-4ecd-a9c2-86f29dda6307', 'artist': 'Chris Rahn', 'frame': '2003', 'full_art': False, 'border_color': 'black', 'timeshifted': False, 'colorshifted': False, 'futureshifted': False, 'edhrec_rank': 855, 'usd': '42.70', 'tix': '2.57', 'eur': '20.95', 'related_uris': {'gatherer': 'http://gatherer.wizards.com/Pages/Card/Details.aspx?multiverseid=221563', 'tcgplayer_decks': 'http://decks.tcgplayer.com/magic/deck/search?contains=Blightsteel+Colossus&page=1&partner=Scryfall', 'edhrec': 'http://edhrec.com/route/?cc=Blightsteel+Colossus', 'mtgtop8': 'http://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Blightsteel+Colossus'}, 'purchase_uris': {'amazon': 'https://www.amazon.com/gp/search?ie=UTF8&index=toys-and-games&keywords=Blightsteel+Colossus&tag=scryfall-20', 'ebay': 'http://rover.ebay.com/rover/1/711-53200-19255-0/1?campid=5337966903&icep_catId=19107&icep_ff3=10&icep_sortBy=12&icep_uq=Blightsteel+Colossus&icep_vectorid=229466&ipn=psmain&kw=lg&kwid=902099&mtid=824&pub=5575230669&toolid=10001', 'tcgplayer': 'https://scryfall.com/s/tcgplayer/39082', 'magiccardmarket': 'https://scryfall.com/s/mcm/245357', 'cardhoarder': 'https://www.cardhoarder.com/cards/39587?affiliate_id=scryfall&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall', 'card_kingdom': 'https://www.cardkingdom.com/catalog/item/137073?partner=scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall', 'mtgo_traders': 'http://www.mtgotraders.com/deck/ref.php?id=39587&referral=scryfall', 'coolstuffinc': 'https://scryfall.com/s/coolstuffinc/1319472'}}, {'object': 'card', 'id': '612beb8f-2ab1-4a8b-84c5-c47d19d400ab', 'oracle_id': '2adbb56a-45e9-4fbe-b586-3488ef8014a3', 'multiverse_ ...

# %%
#from examining the above I can see that I want the 'data' element from the results dictionary,
#which forms most of the content

#let's look at it
results['data']
# Out:
# [{'object': 'card',
#   'id': '7928bb14-7631-4830-a756-26d1ea832ba2',
#   'oracle_id': 'e80772e2-8623-4094-81a2-70828b2b151c',
#   'multiverse_ids': [221563],
#   'mtgo_id': 39587,
#   'mtgo_foil_id': 39588,
#   'name': 'Blightsteel Colossus',
#   'lang': 'en',
#   'uri': 'https://api.scryfall.com/cards/7928bb14-7631-4830-a756-26d1ea832ba2',
#   'scryfall_uri': 'https://scryfall.com/card/mbs/99/blightsteel-colossus?utm_source=api',
#   'layout': 'normal',
#   'highres_image': True,
#   'image_uris': {'small': 'https://img.scryfall.com/cards/small/en/mbs/99.jpg?1517813031',
#    'normal': 'https://img.scryfall.com/cards/normal/en/mbs/99.jpg?1517813031',
#    'large': 'https://img.scryfall.com/cards/large/en/mbs/99.jpg?1517813031',
#    'png': 'https://img.scryfall.com/cards/png/en/mbs/99.png?1517813031',
#    'art_crop': 'https://img.scryfall.com/cards/art_crop/en/mbs/99.jpg?1517813031',
#    'border_crop': 'https://img.scryfall.com/cards/border_crop/en/mbs/99.jpg?1517813031'},
#   'mana_cost': '{12}',
#   'cmc': 12.0,
#   'type_line': 'Artifact Creature — Golem',
#   'oracle_text': "Trample, infect, indestructible\nIf Blightsteel Colossus would be put into a graveyard from anywhere, reveal Blightsteel Colossus and shuffle it into its owner's library instead.",
#   'power': '11',
#   'toughness': '11',
#   'colors': [],
#   'color_identity': [],
#   'legalities': {'standard': 'not_legal',
#    'future': 'not_legal',
#    'frontier': 'not_legal',
#    'modern': 'legal',
#    'legacy': 'legal',
#    'pauper': 'not_legal',
#    'vintage': 'legal',
#    'penny': 'not_legal',
#    'commander': 'legal',
#    '1v1': 'legal',
#    'duel': 'legal',
#    'brawl': 'not_legal'},
#   'reserved': False,
#   'foil': True,
#   'nonfoil': True,
#   'oversized': False,
#   'reprint': False,
#   'set': 'mbs',
#   'set_name': 'Mirrodin Besieged',
#   'set_uri': 'https://api.scryfall.com/sets/mbs',
#   'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Ambs&unique=prints',
#   'scryfall_set_uri': 'https://scryfall.com/sets/mbs?utm_source=api',
#   'rulings_uri': 'https://api.scryfall.com/cards/7928bb14-7631-4830-a756-26d1ea832ba2/rulings',
#   'prints_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=%21%E2%80%9CBlightsteel+Colossus%E2%80%9D+include%3Aextras&unique=prints',
#   'collector_number': '99',
#   'digital': False,
#   'rarity': 'mythic',
#   'watermark': 'phyrexian',
#   'illustration_id': '945af848-56b4-4ecd-a9c2-86f29dda6307',
#   'artist': 'Chris Rahn',
#   'frame': '2003',
#   'full_art': False,
#   'border_color': 'black',
#   'timeshifted': False,
#   'colorshifted': False,
#   'futureshifted': False,
#   'edhrec_rank': 855,
#   'usd': '42.70',
#   'tix': '2.57',
#   'eur': '20.95',
#   'related_uris': {'gatherer': 'http://gatherer.wizards.com/Pages/Card/Details.aspx?multiverseid=221563',
#    'tcgplayer_decks': 'http://decks.tcgplayer.com/magic/deck/search?contains=Blightsteel+Colossus&page=1&partner=Scryfall',
#    'edhrec': 'http://edhrec.com/route/?cc=Blightsteel+Colossus',
#    'mtgtop8': 'http://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Blightsteel+Colossus'},
#   'purchase_uris': {'amazon': 'https://www.amazon.com/gp/search?ie=UTF8&index=toys-and-games&keywords=Blightsteel+Colossus&tag=scryfall-20',
#    'ebay': 'http://rover.ebay.com/rover/1/711-53200-19255-0/1?campid=5337966903&icep_catId=19107&icep_ff3=10&icep_sortBy=12&icep_uq=Blightsteel+Colossus&icep_vectorid=229466&ipn=psmain&kw=lg&kwid=902099&mtid=824&pub=5575230669&toolid=10001',
#    'tcgplayer': 'https://scryfall.com/s/tcgplayer/39082',
#    'magiccardmarket': 'https://scryfall.com/s/mcm/245357',
#    'cardhoarder': 'https://www.cardhoarder.com/cards/39587?affiliate_id=scryfall&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall',
#    'card_kingdom': 'https://www.cardkingdom.com/catalog/item/137073?partner=scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall',
#    'mtgo_traders': 'http://www.mtgotraders.com/deck/ref.php?id=39587&referral=scryfall',
#    'coolstuffinc': 'https://scryfall.com/s/coolstuffinc/1319472'}},
#  {'object': 'card',
#   'id': '612beb8f-2ab1-4a8b-84c5-c47d19d400ab',
#   'oracle_id': '2adbb56a-45e9-4fbe-b586-3488ef8014a3',
#   'multiverse_ids': [366411],
#   'mtgo_id': 47783,
#   'mtgo_foil_id': 47784,
#   'name': 'Enter the Infinite',
#   'lang': 'en',
#   'uri': 'https://api.scryfall.com/cards/612beb8f-2ab1-4a8b-84c5-c47d19d400ab',
#   'scryfall_uri': 'https://scryfall.com/card/gtc/34/enter-the-infinite?utm_source=api',
#   'layout': 'normal',
#   'highres_image': True,
#   'image_uris': {'small': 'https://img.scryfall.com/cards/small/en/gtc/34.jpg?1517813031',
#    'normal': 'https://img.scryfall.com/cards/normal/en/gtc/34.jpg?1517813031',
#    'large': 'https://img.scryfall.com/cards/large/en/gtc/34.jpg?1517813031',
#    'png': 'https://img.scryfall.com/cards/png/en/gtc/34.png?1517813031',
#    'art_crop': 'https://img.scryfall.com/cards/art_crop/en/gtc/34.jpg?1517813031',
#    'border_crop': 'https://img.scryfall.com/cards/border_crop/en/gtc/34.jpg?1517813031'},
#   'mana_cost': '{8}{U}{U}{U}{U}',
#   'cmc': 12.0,
#   'type_line': 'Sorcery',
#   'oracle_text': 'Draw cards equal to the number of cards in your library, then put a card from your hand on top of your library. You have no maximum hand size until your next turn.',
#   'colors': ['U'],
#   'color_identity': ['U'],
#   'legalities': {'standard': 'not_legal',
#    'future': 'not_legal',
#    'frontier': 'not_legal',
#    'modern': 'legal',
#    'legacy': 'legal',
#    'pauper': 'not_legal',
#    'vintage': 'legal',
#    'penny': 'not_legal',
#    'commander': 'legal',
#    '1v1': 'legal',
#    'duel': 'legal',
#    'brawl': 'not_legal'},
#   'reserved': False,
#   'foil': True,
#   'nonfoil': True,
#   'oversized': False,
#   'reprint': False,
#   'set': 'gtc',
#   'set_name': 'Gatecrash',
#   'set_uri': 'https://api.scryfall.com/sets/gtc',
#   'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Agtc&unique=prints',
#   'scryfall_set_uri': 'https://scryfall.com/sets/gtc?utm_source=api',
#   'rulings_uri': 'https://api.scryfall.com/cards/612beb8f-2ab1-4a8b-84c5-c47d19d400ab/rulings',
#   'prints_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=%21%E2%80%9CEnter+the+Infinite%E2%80%9D+include%3Aextras&unique=prints',
#   'collector_number': '34',
#   'digital': False,
#   'rarity': 'mythic',
#   'flavor_text': '"Don\'t just have an idea—have all of them." —Niv-Mizzet',
#   'illustration_id': '69986533-f476-4c7c-9c85-09a571b0ba5c',
#   'artist': 'Terese Nielsen',
#   'frame': '2003',
#   'full_art': False,
#   'border_color': 'black',
#   'timeshifted': False,
#   'colorshifted': False,
#   'futureshifted': False,
#   'edhrec_rank': 1403,
#   'usd': '2.49',
#   'tix': '0.64',
#   'eur': '1.45',
#   'related_uris': {'gatherer': 'http://gatherer.wizards.com/Pages/Card/Details.aspx?multiverseid=366411',
#    'tcgplayer_decks': 'http://decks.tcgplayer.com/magic/deck/search?contains=Enter+the+Infinite&page=1&partner=Scryfall',
#    'edhrec': 'http://edhrec.com/route/?cc=Enter+the+Infinite',
#    'mtgtop8': 'http://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Enter+the+Infinite'},
#   'purchase_uris': {'amazon': 'https://www.amazon.com/gp/search?ie=UTF8&index=toys-and-games&keywords=Enter+the+Infinite&tag=scryfall-20',
#    'ebay': 'http://rover.ebay.com/rover/1/711-53200-19255-0/1?campid=5337966903&icep_catId=19107&icep_ff3=10&icep_sortBy=12&icep_uq=Enter+the+Infinite&icep_vectorid=229466&ipn=psmain&kw=lg&kwid=902099&mtid=824&pub=5575230669&toolid=10001',
#    'tcgplayer': 'https://scryfall.com/s/tcgplayer/67317',
#    'magiccardmarket': 'https://scryfall.com/s/mcm/259801',
#    'cardhoarder': 'https://www.cardhoarder.com/cards/47783?affiliate_id=scryfall&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall',
#    'card_kingdom': 'https://www.cardkingdom.com/catalog/item/188900?partner=scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall',
#    'mtgo_traders': 'http://www.mtgotraders.com/deck/ref.php?id=47783&referral=scryfall',
#    'coolstuffinc': 'https://scryfall.com/s/coolstuffinc/1925050'}},
#  {'object': 'card',
#   'id': '0104b5b3-9376-4ad7-9a77-3e564e9c42e6',
#   'oracle_id': 'b0b6be0c-41cf-4757-9f0e-87227b6ba6b3',
#   'multiverse_ids': [439787],
#   'mtgo_id': 66713,
#   'arena_id': 66877,
#   'name': 'Ghalta, Primal Hunger',
#   'lang': 'en',
#   'uri': 'https://api.scryfall.com/cards/0104b5b3-9376-4ad7-9a77-3e564e9c42e6',
#   'scryfall_uri': 'https://scryfall.com/card/rix/130/ghalta-primal-hunger?utm_source=api',
#   'layout': 'normal',
#   'highres_image': True,
#   'image_uris': {'small': 'https://img.scryfall.com/cards/small/en/rix/130.jpg?1524751787',
#    'normal': 'https://img.scryfall.com/cards/normal/en/rix/130.jpg?1524751787',
#    'large': 'https://img.scryfall.com/cards/large/en/rix/130.jpg?1524751787',
#    'png': 'https://img.scryfall.com/cards/png/en/rix/130.png?1524751787',
#    'art_crop': 'https://img.scryfall.com/cards/art_crop/en/rix/130.jpg?1524751787',
#    'border_crop': 'https://img.scryfall.com/cards/border_crop/en/rix/130.jpg?1524751787'},
#   'mana_cost': '{10}{G}{G}',
#   'cmc': 12.0,
#   'type_line': 'Legendary Creature — Elder Dinosaur',
#   'oracle_text': 'Ghalta, Primal Hunger costs {X} less to cast, where X is the total power of creatures you control.\nTrample',
#   'power': '12',
#   'toughness': '12',
#   'colors': ['G'],
#   'color_identity': ['G'],
#   'legalities': {'standard': 'legal',
#    'future': 'legal',
#    'frontier': 'legal',
#    'modern': 'legal',
#    'legacy': 'legal',
#    'pauper': 'not_legal',
#    'vintage': 'legal',
#    'penny': 'not_legal',
#    'commander': 'legal',
#    '1v1': 'legal',
#    'duel': 'legal',
#    'brawl': 'legal'},
#   'reserved': False,
#   'foil': True,
#   'nonfoil': True,
#   'oversized': False,
#   'reprint': False,
#   'set': 'rix',
#   'set_name': 'Rivals of Ixalan',
#   'set_uri': 'https://api.scryfall.com/sets/rix',
#   'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Arix&unique=prints',
#   'scryfall_set_uri': 'https://scryfall.com/sets/rix?utm_source=api',
#   'rulings_uri': 'https://api.scryfall.com/cards/0104b5b3-9376-4ad7-9a77-3e564e9c42e6/rulings',
#   'prints_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=%21%E2%80%9CGhalta%2C+Primal+Hunger%E2%80%9D+include%3Aextras&unique=prints',
#   'collector_number': '130',
#   'digital': False,
#   'rarity': 'rare',
#   'flavor_text': 'The earth walks, strongest of all.',
#   'illustration_id': 'c3204342-9eea-41f8-9fe3-e6b36c5e3a9c',
#   'artist': 'Chase Stone',
#   'frame': '2015',
#   'full_art': False,
#   'border_color': 'black',
#   'timeshifted': False,
#   'colorshifted': False,
#   'futureshifted': False,
#   'edhrec_rank': 1148,
#   'usd': '8.86',
#   'tix': '2.53',
#   'eur': '6.53',
#   'related_uris': {'gatherer': 'http://gatherer.wizards.com/Pages/Card/Details.aspx?multiverseid=439787',
#    'tcgplayer_decks': 'http://decks.tcgplayer.com/magic/deck/search?contains=Ghalta%2C+Primal+Hunger&page=1&partner=Scryfall',
#    'edhrec': 'http://edhrec.com/route/?cc=Ghalta%2C+Primal+Hunger',
#    'mtgtop8': 'http://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Ghalta%2C+Primal+Hunger'},
#   'purchase_uris': {'amazon': 'https://www.amazon.com/gp/search?ie=UTF8&index=toys-and-games&keywords=Ghalta%2C+Primal+Hunger&tag=scryfall-20',
#    'ebay': 'http://rover.ebay.com/rover/1/711-53200-19255-0/1?campid=5337966903&icep_catId=19107&icep_ff3=10&icep_sortBy=12&icep_uq=Ghalta%2C+Primal+Hunger&icep_vectorid=229466&ipn=psmain&kw=lg&kwid=902099&mtid=824&pub=5575230669&toolid=10001',
#    'tcgplayer': 'https://scryfall.com/s/tcgplayer/155579',
#    'magiccardmarket': 'https://scryfall.com/s/mcm/315286',
#    'cardhoarder': 'https://www.cardhoarder.com/cards/66713?affiliate_id=scryfall&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall',
#    'card_kingdom': 'https://www.cardkingdom.com/catalog/item/216040?partner=scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall',
#    'mtgo_traders': 'http://www.mtgotraders.com/deck/ref.php?id=66713&referral=scryfall',
#    'coolstuffinc': 'https://scryfall.com/s/coolstuffinc/4301082'}},
#  {'object': 'card',
#   'id': '4e13f122-0dfe-42f3-9815-9ae1a29fca99',
#   'oracle_id': '865e569b-6999-4a03-ad02-4bfd595d5820',
#   'multiverse_ids': [74618],
#   'mtgo_id': 22098,
#   'mtgo_foil_id': 22099,
#   'name': 'Iname as One',
#   'lang': 'en',
#   'uri': 'https://api.scryfall.com/cards/4e13f122-0dfe-42f3-9815-9ae1a29fca99',
#   'scryfall_uri': 'https://scryfall.com/card/sok/151/iname-as-one?utm_source=api',
#   'layout': 'normal',
#   'highres_image': True,
#   'image_uris': {'small': 'https://img.scryfall.com/cards/small/en/sok/151.jpg?1517813031',
#    'normal': 'https://img.scryfall.com/cards/normal/en/sok/151.jpg?1517813031',
#    'large': 'https://img.scryfall.com/cards/large/en/sok/151.jpg?1517813031',
#    'png': 'https://img.scryfall.com/cards/png/en/sok/151.png?1517813031',
#    'art_crop': 'https://img.scryfall.com/cards/art_crop/en/sok/151.jpg?1517813031',
#    'border_crop': 'https://img.scryfall.com/cards/border_crop/en/sok/151.jpg?1517813031'},
#   'mana_cost': '{8}{B}{B}{G}{G}',
#   'cmc': 12.0,
#   'type_line': 'Legendary Creature — Spirit',
#   'oracle_text': 'When Iname as One enters the battlefield, if you cast it from your hand, you may search your library for a Spirit permanent card, put it onto the battlefield, then shuffle your library.\nWhen Iname as One dies, you may exile it. If you do, return target Spirit permanent card from your graveyard to the battlefield.',
#   'power': '8',
#   'toughness': '8',
#   'colors': ['B', 'G'],
#   'color_identity': ['B', 'G'],
#   'legalities': {'standard': 'not_legal',
#    'future': 'not_legal',
#    'frontier': 'not_legal',
#    'modern': 'legal',
#    'legacy': 'legal',
#    'pauper': 'not_legal',
#    'vintage': 'legal',
#    'penny': 'not_legal',
#    'commander': 'legal',
#    '1v1': 'legal',
#    'duel': 'legal',
#    'brawl': 'not_legal'},
#   'reserved': False,
#   'foil': True,
#   'nonfoil': True,
#   'oversized': False,
#   'reprint': False,
#   'set': 'sok',
#   'set_name': 'Saviors of Kamigawa',
#   'set_uri': 'https://api.scryfall.com/sets/sok',
#   'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Asok&unique=prints',
#   'scryfall_set_uri': 'https://scryfall.com/sets/sok?utm_source=api',
#   'rulings_uri': 'https://api.scryfall.com/cards/4e13f122-0dfe-42f3-9815-9ae1a29fca99/rulings',
#   'prints_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=%21%E2%80%9CIname+as+One%E2%80%9D+include%3Aextras&unique=prints',
#   'collector_number': '151',
#   'digital': False,
#   'rarity': 'rare',
#   'illustration_id': '5629b060-7b50-4e2f-b08b-6986c1f756e8',
#   'artist': 'Stephen Tappin',
#   'frame': '2003',
#   'full_art': False,
#   'border_color': 'black',
#   'timeshifted': False,
#   'colorshifted': False,
#   'futureshifted': False,
#   'edhrec_rank': 10067,
#   'usd': '0.53',
#   'tix': '0.01',
#   'eur': '0.55',
#   'related_uris': {'gatherer': 'http://gatherer.wizards.com/Pages/Card/Details.aspx?multiverseid=74618',
#    'tcgplayer_decks': 'http://decks.tcgplayer.com/magic/deck/search?contains=Iname+as+One&page=1&partner=Scryfall',
#    'edhrec': 'http://edhrec.com/route/?cc=Iname+as+One',
#    'mtgtop8': 'http://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Iname+as+One'},
#   'purchase_uris': {'amazon': 'https://www.amazon.com/gp/search?ie=UTF8&index=toys-and-games&keywords=Iname+as+One&tag=scryfall-20',
#    'ebay': 'http://rover.ebay.com/rover/1/711-53200-19255-0/1?campid=5337966903&icep_catId=19107&icep_ff3=10&icep_sortBy=12&icep_uq=Iname+as+One&icep_vectorid=229466&ipn=psmain&kw=lg&kwid=902099&mtid=824&pub=5575230669&toolid=10001',
#    'tcgplayer': 'https://scryfall.com/s/tcgplayer/12455',
#    'magiccardmarket': 'https://scryfall.com/s/mcm/12683',
#    'cardhoarder': 'https://www.cardhoarder.com/cards/22098?affiliate_id=scryfall&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall',
#    'card_kingdom': 'https://www.cardkingdom.com/catalog/item/117062?partner=scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall',
#    'mtgo_traders': 'http://www.mtgotraders.com/deck/ref.php?id=22098&referral=scryfall',
#    'coolstuffinc': 'https://scryfall.com/s/coolstuffinc/1420956'}},
#  {'object': 'card',
#   'id': '5b64cfc0-dace-4f54-b2b1-c92d8cb64c35',
#   'oracle_id': 'b11187ab-f8a8-422b-b550-4495f96de0f2',
#   'multiverse_ids': [401685],
#   'name': 'It That Betrays',
#   'lang': 'en',
#   'uri': 'https://api.scryfall.com/cards/5b64cfc0-dace-4f54-b2b1-c92d8cb64c35',
#   'scryfall_uri': 'https://scryfall.com/card/ddp/43/it-that-betrays?utm_source=api',
#   'layout': 'normal',
#   'highres_image': True,
#   'image_uris': {'small': 'https://img.scryfall.com/cards/small/en/ddp/43.jpg?1530591421',
#    'normal': 'https://img.scryfall.com/cards/normal/en/ddp/43.jpg?1530591421',
#    'large': 'https://img.scryfall.com/cards/large/en/ddp/43.jpg?1530591421',
#    'png': 'https://img.scryfall.com/cards/png/en/ddp/43.png?1530591421',
#    'art_crop': 'https://img.scryfall.com/cards/art_crop/en/ddp/43.jpg?1530591421',
#    'border_crop': 'https://img.scryfall.com/cards/border_crop/en/ddp/43.jpg?1530591421'},
#   'mana_cost': '{12}',
#   'cmc': 12.0,
#   'type_line': 'Creature — Eldrazi',
#   'oracle_text': 'Annihilator 2 (Whenever this creature attacks, defending player sacrifices two permanents.)\nWhenever an opponent sacrifices a nontoken permanent, put that card onto the battlefield under your control.',
#   'power': '11',
#   'toughness': '11',
#   'colors': [],
#   'color_identity': [],
#   'legalities': {'standard': 'not_legal',
#    'future': 'not_legal',
#    'frontier': 'not_legal',
#    'modern': 'legal',
#    'legacy': 'legal',
#    'pauper': 'not_legal',
#    'vintage': 'legal',
#    'penny': 'not_legal',
#    'commander': 'legal',
#    '1v1': 'legal',
#    'duel': 'legal',
#    'brawl': 'not_legal'},
#   'reserved': False,
#   'foil': False,
#   'nonfoil': True,
#   'oversized': False,
#   'reprint': True,
#   'set': 'ddp',
#   'set_name': 'Duel Decks: Zendikar vs. Eldrazi',
#   'set_uri': 'https://api.scryfall.com/sets/ddp',
#   'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Addp&unique=prints',
#   'scryfall_set_uri': 'https://scryfall.com/sets/ddp?utm_source=api',
#   'rulings_uri': 'https://api.scryfall.com/cards/5b64cfc0-dace-4f54-b2b1-c92d8cb64c35/rulings',
#   'prints_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=%21%E2%80%9CIt+That+Betrays%E2%80%9D+include%3Aextras&unique=prints',
#   'collector_number': '43',
#   'digital': False,
#   'rarity': 'rare',
#   'flavor_text': 'Your pleas for death shall go unheard.',
#   'illustration_id': '351a81c2-7bc9-4cbb-871f-85d96f34162f',
#   'artist': 'Tomasz Jedruszek',
#   'frame': '2015',
#   'full_art': False,
#   'border_color': 'black',
#   'timeshifted': False,
#   'colorshifted': False,
#   'futureshifted': False,
#   'edhrec_rank': 652,
#   'usd': '6.36',
#   'eur': '2.89',
#   'related_uris': {'gatherer': 'http://gatherer.wizards.com/Pages/Card/Details.aspx?multiverseid=401685',
#    'tcgplayer_decks': 'http://decks.tcgplayer.com/magic/deck/search?contains=It+That+Betrays&page=1&partner=Scryfall',
#    'edhrec': 'http://edhrec.com/route/?cc=It+That+Betrays',
#    'mtgtop8': 'http://mtgtop8.com/search?MD_check=1&SB_check=1&cards=It+That+Betrays'},
#   'purchase_uris': {'amazon': 'https://www.amazon.com/gp/search?ie=UTF8&index=toys-and-games&keywords=It+That+Betrays&tag=scryfall-20',
#    'ebay': 'http://rover.ebay.com/rover/1/711-53200-19255-0/1?campid=5337966903&icep_catId=19107&icep_ff3=10&icep_sortBy=12&icep_uq=It+That+Betrays&icep_vectorid=229466&ipn=psmain&kw=lg&kwid=902099&mtid=824&pub=5575230669&toolid=10001',
#    'tcgplayer': 'https://scryfall.com/s/tcgplayer/104234',
#    'magiccardmarket': 'https://scryfall.com/s/mcm/284150',
#    'cardhoarder': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=It+That+Betrays&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall',
#    'card_kingdom': 'https://www.cardkingdom.com/catalog/item/202376?partner=scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall',
#    'mtgo_traders': 'http://www.mtgotraders.com/store/search.php?q=It+That+Betrays&referral=scryfall',
#    'coolstuffinc': 'https://scryfall.com/s/coolstuffinc/2795082'}}]

# %%
#use len to see how many items are in the results['data'] for this response
print('results["data"] contains '+str(len(results['data']))+' elements')
# Out:
# results["data"] contains 5 elements

# %% [markdown]
# Now that the I can see the card data, the next challenge is to extract the bits I want.. I will try for the 4th element (chosen randomly) and see if I can actually get the elements I need, which are 'card name', 'set', 'proxy for cardkingdom price', and 'cardmarket trend price'... I can get them all as shown below by referencing nested elements of the results['data'] sub-dictionaries. There are loads more available. You can get them by studying the output above and experimenting a bit more

# %%
#learn how to extract the data I want
print('name='+results['data'][4]['name'])
print('set_name='+results['data'][4]['set_name'])
print('set='+results['data'][4]['set'])
print('usd='+results['data'][4]['usd'])
print('eur='+str(results['data'][4]['eur']))
# Out:
# name=It That Betrays
# set_name=Duel Decks: Zendikar vs. Eldrazi
# set=ddp
# usd=6.36
# eur=2.89

# %% [markdown]
# #### Loop It
# Last thing to do now is just extract the above elements in a loop--looping through all the elements in the dictionary. You can see that below I am just identifying them for each element in results['data'] (i.e. for each card returned)
#
# Then once identified, I store them to a temp dataframe called df; then finally append that df to my repository dataframe (repo).
#
# Lastly, I just output the repo dataframe to a csv file

# %%
#loop through the results and hive the good stuff
repo=pd.DataFrame()
for i in range(0,len(results['data'])):
    card_name=results['data'][i]['name']
    set_name=results['data'][i]['set_name']
    set_tckr=results['data'][i]['set']
    usd=results['data'][i]['usd']
    eur=results['data'][i]['eur']
    df=pd.DataFrame({'card_name':[card_name],
                     'set':set_tckr,
                    'set_name':set_name,
                    'usd':usd,
                    'eur':eur})
    repo=repo.append(df,ignore_index=True)

#preview the dataframe
print(repo)

#store current date (for filename later)
currdate=datetime.datetime.today().strftime('%Y%m%d')
repo.to_csv('cards_'+currdate+'.csv',index=False) #write the df to a csv using the datestamp from above
# Out:
#                card_name  set                          set_name    usd    eur
# 0   Blightsteel Colossus  mbs                 Mirrodin Besieged  42.70  20.95
# 1     Enter the Infinite  gtc                         Gatecrash   2.49   1.45
# 2  Ghalta, Primal Hunger  rix                  Rivals of Ixalan   8.86   6.53
# 3           Iname as One  sok               Saviors of Kamigawa   0.53   0.55
# 4        It That Betrays  ddp  Duel Decks: Zendikar vs. Eldrazi   6.36   2.89
